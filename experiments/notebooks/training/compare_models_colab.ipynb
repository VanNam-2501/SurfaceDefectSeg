# %% [markdown]
# # Compare final experiments

# %%
from google.colab import drive
drive.mount("/content/drive")

from pathlib import Path
PROJECT = Path("/content/TTTN")
assert PROJECT.exists(), "Upload/unzip the project to /content/TTTN first"
assert (PROJECT / "data" / "3cad_ani").exists(), "Dataset missing at /content/TTTN/data/3cad_ani"
# %cd /content/TTTN

# %%
# !python compare_models.py

# %%
from IPython.display import display, Image
import pandas as pd
base="results/comparison"
display(pd.read_csv(f"{base}/main_metrics.csv"))
display(pd.read_csv(f"{base}/efficiency.csv"))
display(pd.read_csv(f"{base}/defect_size_metrics.csv"))
display(pd.read_csv(f"{base}/defect_group_metrics.csv"))
display(pd.read_csv(f"{base}/multi_region_metrics.csv"))
display(Image(f"{base}/architecture_comparison.png"))
display(Image(f"{base}/efficiency_comparison.png"))

# %% [markdown]
# ## Optional E9 — after seeds 42, 123, 2026 exist

# %%
# !python compare_seeds.py
